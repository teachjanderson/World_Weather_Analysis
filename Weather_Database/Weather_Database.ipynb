# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module.
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the requests library. 
import requests

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description=city_weather["weather"][0]["description"]
     
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | popondetta
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | ostersund
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | lock haven
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | antalaha
# Processing Record 12 of Set 1 | tlaxiaco
# City not found. Skipping...
# Processing Record 13 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 1 | brownsville
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | birao
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | srednekolymsk
# Processing Record 19 of Set 1 | morondava
# Processing Record 20 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 1 | rognan
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | tommot
# Processing Record 25 of Set 1 | baghdad
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | cabedelo
# Processing Record 29 of Set 1 | kichera
# Processing Record 30 of Set 1 | cowra
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | parrita
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | roald
# Processing Record 35 of Set 1 | sao filipe
# Processing Record 36 of Set 1 | udayagiri
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | lubao
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | deputatskiy
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | sindor
# Processing Record 43 of Set 1 | eyl
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | te anau
# Processing Record 46 of Set 1 | wanaka
# Processing Record 47 of Set 1 | sorland
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | richards bay
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | dahra
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | kalamakion
# City not found. Skipping...
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | sao joao da barra
# Processing Record 9 of Set 2 | portland
# Processing Record 10 of Set 2 | kahului
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | nishihara
# Processing Record 15 of Set 2 | kemijarvi
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | camalu
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | vilcun
# Processing Record 24 of Set 2 | atar
# Processing Record 25 of Set 2 | amahai
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | mirnyy
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | den helder
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | evensk
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | otrado-olginskoye
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | boden
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | sarangani
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | voskevan
# Processing Record 47 of Set 2 | lodja
# Processing Record 48 of Set 2 | ust-maya
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | saint-denis
# Processing Record 2 of Set 3 | baherden
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | andros town
# Processing Record 5 of Set 3 | abu kamal
# Processing Record 6 of Set 3 | pandan
# Processing Record 7 of Set 3 | port macquarie
# Processing Record 8 of Set 3 | saint-augustin
# Processing Record 9 of Set 3 | faya
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | xifeng
# Processing Record 12 of Set 3 | shellbrook
# Processing Record 13 of Set 3 | buala
# Processing Record 14 of Set 3 | hangal
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | emerald
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | laguna
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | yarim
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | sikonge
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | kaeo
# Processing Record 29 of Set 3 | kilindoni
# Processing Record 30 of Set 3 | ambilobe
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | laem sing
# Processing Record 34 of Set 3 | huarmey
# Processing Record 35 of Set 3 | kondinskoye
# Processing Record 36 of Set 3 | immokalee
# Processing Record 37 of Set 3 | quatre cocos
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | camargo
# Processing Record 40 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | valdivia
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | coos bay
# Processing Record 45 of Set 3 | barrow
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | lewistown
# Processing Record 48 of Set 3 | bekwai
# Processing Record 49 of Set 3 | wajir
# Processing Record 50 of Set 3 | necochea
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | gazli
# Processing Record 4 of Set 4 | meulaboh
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | bodden town
# Processing Record 11 of Set 4 | bagdarin
# Processing Record 12 of Set 4 | dzhebariki-khaya
# Processing Record 13 of Set 4 | aleksandrov gay
# Processing Record 14 of Set 4 | tucuman
# Processing Record 15 of Set 4 | khandbari
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | schwechat
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | kendari
# Processing Record 20 of Set 4 | atyrau
# Processing Record 21 of Set 4 | kieta
# Processing Record 22 of Set 4 | danshui
# Processing Record 23 of Set 4 | jeremie
# Processing Record 24 of Set 4 | gerash
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | la ronge
# Processing Record 27 of Set 4 | sovetskiy
# Processing Record 28 of Set 4 | safakulevo
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | kautokeino
# Processing Record 31 of Set 4 | osecina
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | quelimane
# Processing Record 36 of Set 4 | general roca
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | tambo
# Processing Record 40 of Set 4 | axim
# Processing Record 41 of Set 4 | changji
# Processing Record 42 of Set 4 | batagay-alyta
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | puerto escondido
# Processing Record 45 of Set 4 | honiara
# Processing Record 46 of Set 4 | kizema
# Processing Record 47 of Set 4 | beyneu
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | vermillion
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | belmonte
# Processing Record 2 of Set 5 | concordia
# Processing Record 3 of Set 5 | esperance
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | nantucket
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | aki
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | soubre
# Processing Record 11 of Set 5 | puerto ayora
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | ulety
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | bredy
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | shelburne
# Processing Record 18 of Set 5 | kalga
# Processing Record 19 of Set 5 | tabou
# Processing Record 20 of Set 5 | batemans bay
# Processing Record 21 of Set 5 | wolmaranstad
# City not found. Skipping...
# Processing Record 22 of Set 5 | kavaratti
# Processing Record 23 of Set 5 | butaritari
# Processing Record 24 of Set 5 | el silencio
# Processing Record 25 of Set 5 | kalmunai
# Processing Record 26 of Set 5 | vallenar
# Processing Record 27 of Set 5 | meiganga
# Processing Record 28 of Set 5 | kokopo
# Processing Record 29 of Set 5 | fort nelson
# Processing Record 30 of Set 5 | sesheke
# Processing Record 31 of Set 5 | cururupu
# Processing Record 32 of Set 5 | ipixuna
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | liverpool
# Processing Record 35 of Set 5 | ahuimanu
# Processing Record 36 of Set 5 | quebec
# Processing Record 37 of Set 5 | denpasar
# Processing Record 38 of Set 5 | mandalgovi
# Processing Record 39 of Set 5 | zhezkazgan
# Processing Record 40 of Set 5 | cape town
# Processing Record 41 of Set 5 | kismayo
# Processing Record 42 of Set 5 | kaohsiung
# Processing Record 43 of Set 5 | puri
# Processing Record 44 of Set 5 | martapura
# Processing Record 45 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 5 | kjollefjord
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | rabo de peixe
# Processing Record 49 of Set 5 | bumba
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | bantou
# Processing Record 2 of Set 6 | harper
# Processing Record 3 of Set 6 | mount isa
# Processing Record 4 of Set 6 | coffs harbour
# Processing Record 5 of Set 6 | mackay
# Processing Record 6 of Set 6 | road town
# Processing Record 7 of Set 6 | perth
# Processing Record 8 of Set 6 | ossora
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | monrovia
# Processing Record 11 of Set 6 | pfullendorf
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | tiznit
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | alikalia
# Processing Record 17 of Set 6 | desbiens
# Processing Record 18 of Set 6 | sayaxche
# Processing Record 19 of Set 6 | rzhev
# Processing Record 20 of Set 6 | dombarovskiy
# Processing Record 21 of Set 6 | gilgit
# Processing Record 22 of Set 6 | praya
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | saldanha
# Processing Record 25 of Set 6 | kasongo-lunda
# Processing Record 26 of Set 6 | ocos
# Processing Record 27 of Set 6 | bukama
# Processing Record 28 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | cabo san lucas
# Processing Record 33 of Set 6 | sangar
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | fort walton beach
# Processing Record 36 of Set 6 | andra
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | kouango
# Processing Record 39 of Set 6 | chulman
# Processing Record 40 of Set 6 | anshun
# Processing Record 41 of Set 6 | marawi
# Processing Record 42 of Set 6 | inta
# Processing Record 43 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 6 | porto velho
# Processing Record 45 of Set 6 | luwuk
# Processing Record 46 of Set 6 | cayenne
# Processing Record 47 of Set 6 | pundaguitan
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | lazaro cardenas
# Processing Record 50 of Set 6 | chiredzi
# Processing Record 1 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 7 | auki
# Processing Record 3 of Set 7 | solnechnyy
# Processing Record 4 of Set 7 | dolores
# Processing Record 5 of Set 7 | gombong
# Processing Record 6 of Set 7 | havoysund
# Processing Record 7 of Set 7 | linhares
# Processing Record 8 of Set 7 | turukhansk
# Processing Record 9 of Set 7 | tshela
# Processing Record 10 of Set 7 | awbari
# Processing Record 11 of Set 7 | ryazanskaya
# Processing Record 12 of Set 7 | kurilsk
# Processing Record 13 of Set 7 | naron
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | shingu
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | saint-francois
# Processing Record 19 of Set 7 | georgetown
# Processing Record 20 of Set 7 | ottawa
# Processing Record 21 of Set 7 | avdon
# Processing Record 22 of Set 7 | wladyslawowo
# Processing Record 23 of Set 7 | jomalig
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | maceio
# Processing Record 26 of Set 7 | morehead
# Processing Record 27 of Set 7 | abbeville
# Processing Record 28 of Set 7 | borogontsy
# Processing Record 29 of Set 7 | sistranda
# Processing Record 30 of Set 7 | alugan
# Processing Record 31 of Set 7 | tilichiki
# Processing Record 32 of Set 7 | nata
# Processing Record 33 of Set 7 | pitimbu
# Processing Record 34 of Set 7 | verkhoyansk
# Processing Record 35 of Set 7 | kutum
# Processing Record 36 of Set 7 | surt
# Processing Record 37 of Set 7 | dubovskoye
# Processing Record 38 of Set 7 | bara
# Processing Record 39 of Set 7 | laguna de perlas
# Processing Record 40 of Set 7 | hornepayne
# Processing Record 41 of Set 7 | hay river
# Processing Record 42 of Set 7 | kavieng
# Processing Record 43 of Set 7 | homer
# Processing Record 44 of Set 7 | banyo
# Processing Record 45 of Set 7 | port-cartier
# Processing Record 46 of Set 7 | catamarca
# Processing Record 47 of Set 7 | umba
# Processing Record 48 of Set 7 | tornio
# Processing Record 49 of Set 7 | korla
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | bharatpur
# Processing Record 2 of Set 8 | klaksvik
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | ashland
# Processing Record 5 of Set 8 | itacarambi
# Processing Record 6 of Set 8 | yumen
# Processing Record 7 of Set 8 | lensk
# Processing Record 8 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 9 of Set 8 | belle glade
# Processing Record 10 of Set 8 | polson
# Processing Record 11 of Set 8 | baculin
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | mareeba
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | rumford
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 18 of Set 8 | san luis
# Processing Record 19 of Set 8 | royan
# Processing Record 20 of Set 8 | bontang
# Processing Record 21 of Set 8 | doha
# Processing Record 22 of Set 8 | paamiut
# Processing Record 23 of Set 8 | hualmay
# Processing Record 24 of Set 8 | pravda
# Processing Record 25 of Set 8 | dunedin
# Processing Record 26 of Set 8 | ushtobe
# Processing Record 27 of Set 8 | morros
# Processing Record 28 of Set 8 | mudkhed
# Processing Record 29 of Set 8 | jiwani
# Processing Record 30 of Set 8 | lagoa
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | oistins
# Processing Record 34 of Set 8 | malibu
# Processing Record 35 of Set 8 | aksarka
# Processing Record 36 of Set 8 | itaituba
# Processing Record 37 of Set 8 | montbrison
# Processing Record 38 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 39 of Set 8 | clyde river
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | petit-bourg
# Processing Record 42 of Set 8 | miramar
# Processing Record 43 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 44 of Set 8 | severo-kurilsk
# Processing Record 45 of Set 8 | madang
# Processing Record 46 of Set 8 | evans
# Processing Record 47 of Set 8 | okhotsk
# Processing Record 48 of Set 8 | winneba
# Processing Record 49 of Set 8 | bima
# Processing Record 50 of Set 8 | sevierville
# Processing Record 1 of Set 9 | yuxia
# Processing Record 2 of Set 9 | arman
# Processing Record 3 of Set 9 | kawalu
# Processing Record 4 of Set 9 | hambantota
# Processing Record 5 of Set 9 | ternate
# Processing Record 6 of Set 9 | bone
# Processing Record 7 of Set 9 | lavrentiya
# Processing Record 8 of Set 9 | deming
# Processing Record 9 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 10 of Set 9 | arlit
# Processing Record 11 of Set 9 | ugoofaaru
# Processing Record 12 of Set 9 | anloga
# Processing Record 13 of Set 9 | pattaya
# Processing Record 14 of Set 9 | cidreira
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | port dover
# Processing Record 17 of Set 9 | dingle
# Processing Record 18 of Set 9 | port lincoln
# Processing Record 19 of Set 9 | havre-saint-pierre
# Processing Record 20 of Set 9 | ust-nera
# Processing Record 21 of Set 9 | ambulu
# Processing Record 22 of Set 9 | brae
# Processing Record 23 of Set 9 | lac du bonnet
# Processing Record 24 of Set 9 | jiuquan
# Processing Record 25 of Set 9 | jiazi
# Processing Record 26 of Set 9 | limbang
# Processing Record 27 of Set 9 | kokstad
# Processing Record 28 of Set 9 | vicksburg
# Processing Record 29 of Set 9 | litovko
# Processing Record 30 of Set 9 | buraydah
# Processing Record 31 of Set 9 | gobabis
# Processing Record 32 of Set 9 | nyaunglebin
# Processing Record 33 of Set 9 | charyshskoye
# Processing Record 34 of Set 9 | machilipatnam
# Processing Record 35 of Set 9 | majalgaon
# Processing Record 36 of Set 9 | santa lucia
# Processing Record 37 of Set 9 | novoagansk
# Processing Record 38 of Set 9 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 39 of Set 9 | panzhihua
# Processing Record 40 of Set 9 | tabasco
# Processing Record 41 of Set 9 | atka
# City not found. Skipping...
# Processing Record 42 of Set 9 | hobyo
# Processing Record 43 of Set 9 | nioro
# Processing Record 44 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 9 | serabu
# Processing Record 46 of Set 9 | harnosand
# Processing Record 47 of Set 9 | turayf
# Processing Record 48 of Set 9 | smidovich
# Processing Record 49 of Set 9 | seoul
# Processing Record 50 of Set 9 | mandera
# Processing Record 1 of Set 10 | goundam
# Processing Record 2 of Set 10 | palana
# Processing Record 3 of Set 10 | zhob
# Processing Record 4 of Set 10 | kingman
# Processing Record 5 of Set 10 | vostok
# Processing Record 6 of Set 10 | lethem
# Processing Record 7 of Set 10 | corning
# Processing Record 8 of Set 10 | chenzhou
# Processing Record 9 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 10 | borgarnes
# Processing Record 11 of Set 10 | cap malheureux
# Processing Record 12 of Set 10 | krylovskaya
# Processing Record 13 of Set 10 | nuuk
# Processing Record 14 of Set 10 | asau
# Processing Record 15 of Set 10 | xai-xai
# Processing Record 16 of Set 10 | honningsvag
# Processing Record 17 of Set 10 | sioux lookout
# Processing Record 18 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 19 of Set 10 | anadyr
# Processing Record 20 of Set 10 | luderitz
# Processing Record 21 of Set 10 | matara
# Processing Record 22 of Set 10 | buchanan
# Processing Record 23 of Set 10 | luanda
# Processing Record 24 of Set 10 | polewali
# Processing Record 25 of Set 10 | inhambane
# Processing Record 26 of Set 10 | qasigiannguit
# Processing Record 27 of Set 10 | iralaya
# Processing Record 28 of Set 10 | lexington park
# Processing Record 29 of Set 10 | gizo
# Processing Record 30 of Set 10 | yar-sale
# Processing Record 31 of Set 10 | livingston
# Processing Record 32 of Set 10 | san vicente
# Processing Record 33 of Set 10 | port blair
# Processing Record 34 of Set 10 | bakaly
# Processing Record 35 of Set 10 | rize
# Processing Record 36 of Set 10 | matagami
# Processing Record 37 of Set 10 | tual
# Processing Record 38 of Set 10 | sarai naurang
# Processing Record 39 of Set 10 | san rafael
# Processing Record 40 of Set 10 | dawei
# Processing Record 41 of Set 10 | oranjestad
# Processing Record 42 of Set 10 | dhidhdhoo
# Processing Record 43 of Set 10 | aldan
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | muros
# Processing Record 46 of Set 10 | osa
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | neiafu
# Processing Record 49 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 10 | walvis bay
# Processing Record 1 of Set 11 | chicama
# Processing Record 2 of Set 11 | pochutla
# Processing Record 3 of Set 11 | tias
# Processing Record 4 of Set 11 | mehamn
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | sakaraha
# Processing Record 8 of Set 11 | bama
# Processing Record 9 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 11 | fianarantsoa
# Processing Record 12 of Set 11 | praia da vitoria
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | tanout
# Processing Record 15 of Set 11 | sarab
# Processing Record 16 of Set 11 | carbonia
# Processing Record 17 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 11 | iquique
# Processing Record 19 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 11 | dharchula
# Processing Record 21 of Set 11 | oxapampa
# Processing Record 22 of Set 11 | saint-georges
# Processing Record 23 of Set 11 | yarkovo
# Processing Record 24 of Set 11 | esqueda
# Processing Record 25 of Set 11 | catemaco
# Processing Record 26 of Set 11 | half moon bay
# Processing Record 27 of Set 11 | belaya gora
# Processing Record 28 of Set 11 | baboua
# City not found. Skipping...
# Processing Record 29 of Set 11 | udachnyy
# Processing Record 30 of Set 11 | kununurra
# Processing Record 31 of Set 11 | luxor
# Processing Record 32 of Set 11 | hamilton
# Processing Record 33 of Set 11 | bandarbeyla
# Processing Record 34 of Set 11 | cankuzo
# Processing Record 35 of Set 11 | tezu
# Processing Record 36 of Set 11 | gonbad-e qabus
# Processing Record 37 of Set 11 | kabare
# Processing Record 38 of Set 11 | college
# Processing Record 39 of Set 11 | russellville
# Processing Record 40 of Set 11 | koumac
# Processing Record 41 of Set 11 | muzhi
# Processing Record 42 of Set 11 | grand island
# Processing Record 43 of Set 11 | fortuna
# Processing Record 44 of Set 11 | pangai
# Processing Record 45 of Set 11 | acheng
# Processing Record 46 of Set 11 | samarai
# Processing Record 47 of Set 11 | nabire
# Processing Record 48 of Set 11 | ulaangom
# Processing Record 49 of Set 11 | nicoya
# Processing Record 50 of Set 11 | yertsevo
# Processing Record 1 of Set 12 | kloulklubed
# Processing Record 2 of Set 12 | meadow lake
# Processing Record 3 of Set 12 | bardiyah
# Processing Record 4 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 12 | xining
# Processing Record 6 of Set 12 | shenjiamen
# Processing Record 7 of Set 12 | champerico
# Processing Record 8 of Set 12 | caravelas
# Processing Record 9 of Set 12 | shilovo
# Processing Record 10 of Set 12 | venado tuerto
# Processing Record 11 of Set 12 | vanavara
# Processing Record 12 of Set 12 | urumqi
# Processing Record 13 of Set 12 | pacific grove
# Processing Record 14 of Set 12 | alice springs
# Processing Record 15 of Set 12 | salalah
# Processing Record 16 of Set 12 | tacuarembo
# Processing Record 17 of Set 12 | mazamari
# Processing Record 18 of Set 12 | taltal
# Processing Record 19 of Set 12 | san carlos de bariloche
# Processing Record 20 of Set 12 | tadine
# Processing Record 21 of Set 12 | mashivka
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | aykhal
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | gualeguay
# Processing Record 26 of Set 12 | miraflores
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | wattegama
# Processing Record 29 of Set 12 | turbat
# Processing Record 30 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 12 | wiarton
# Processing Record 32 of Set 12 | doksy
# Processing Record 33 of Set 12 | kindersley
# Processing Record 34 of Set 12 | high prairie
# Processing Record 35 of Set 12 | dalby
# Processing Record 36 of Set 12 | lao cai
# Processing Record 37 of Set 12 | kangalassy
# Processing Record 38 of Set 12 | cradock
# Processing Record 39 of Set 12 | moskovskiy
# Processing Record 40 of Set 12 | kidal
# Processing Record 41 of Set 12 | punta cardon
# Processing Record 42 of Set 12 | atambua
# Processing Record 43 of Set 12 | high level
# Processing Record 44 of Set 12 | malakal
# Processing Record 45 of Set 12 | galbinasi
# Processing Record 46 of Set 12 | salvador
# Processing Record 47 of Set 12 | lar
# Processing Record 48 of Set 12 | sibolga
# Processing Record 49 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 12 | ormara
# Processing Record 1 of Set 13 | tharad
# Processing Record 2 of Set 13 | kysyl-syr
# Processing Record 3 of Set 13 | riyadh
# Processing Record 4 of Set 13 | biloela
# Processing Record 5 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 13 | warri
# Processing Record 7 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 13 | khalkhal
# Processing Record 9 of Set 13 | linqing
# Processing Record 10 of Set 13 | rawlins
# Processing Record 11 of Set 13 | mlowo
# Processing Record 12 of Set 13 | sept-iles
# Processing Record 13 of Set 13 | andenes
# Processing Record 14 of Set 13 | ramasukha
# City not found. Skipping...
# Processing Record 15 of Set 13 | boa vista
# Processing Record 16 of Set 13 | gunjur
# Processing Record 17 of Set 13 | hoi an
# Processing Record 18 of Set 13 | rungata
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 569

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff      NZ -46.6000  168.3333     50.81        90          55
# 1    Popondetta      PG  -8.7537  148.2534     74.44        92          97
# 2   New Norfolk      AU -42.7826  147.0587     42.71        77          23
# 3     Ostersund      SE  63.1792   14.6357     39.65        60          75
# 4        Hasaki      JP  35.7333  140.8333     61.20        49         100
# 5  Punta Arenas      CL -53.1500  -70.9167     46.51        57          40
# 6     Fairbanks      US  64.8378 -147.7164     39.09        74         100
# 7      Cherskiy      RU  68.7500  161.3000      7.75        96          93
# 8    Lock Haven      US  41.1370  -77.4469     64.90        37           0
# 9    Nikolskoye      RU  59.7035   30.7861     43.72        74          60
#
#    Wind Speed Current Description
# 0        2.37       moderate rain
# 1        2.93     overcast clouds
# 2        2.39          few clouds
# 3       10.36       broken clouds
# 4       12.77     overcast clouds
# 5       27.63    scattered clouds
# 6        5.75     overcast clouds
# 7        3.36     overcast clouds
# 8        9.53           clear sky
# 9        5.06       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
